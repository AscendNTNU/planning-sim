# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from Valueiteration3d import *
# Out:
# 2018-04-23 16:27:28

# %%
valueiteration() # valueiteration for robots and actions
# Out:
# Iteration 500 out of 500
#
# grid complete!

# %%
angle = 11 # can be changed from 0 to 11, to change the angle
printAngle(angle)
showGrid(valuegrid[:,:,angle])
# Out:
# ---- Angle ----
# Radians:  2.62
# Degrees:  150.0
# ---------------
# <img src="data:image/png;base64,...">

# %%
showGrid(valuegrid[:,:,0])
# Out:
# <img src="data:image/png;base64,...">

# %%
showGrid(actiongrid[:,:,0], 1,3)
# Out:
# <img src="data:image/png;base64,...">

# %%
printGrid(actiongrid)
# Out:
# [[ 2.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.  2.]
#  [ 2.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.  2.]
#  [ 2.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.  2.]
#  [ 2.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.  2.]
#  [ 2.  1.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  3.  3.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  3.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.  2.]
#  [ 2.  2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.]
#  [ 3.  2.  1.  1.  1.  1.  1.  1.  3.  3.  3.  3.]
#  [ 3.  2.  2.  1.  1.  1.  1.  1.  1.  3.  3.  3.]
# ...

# %%
showGrid(valuegrid[:,:,6])
# Out:
# <img src="data:image/png;base64,...">
