# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from Valueiteration3d import *
# Out:
# 2018-05-03 14:11:26
# Iteration 1000 out of 1000
#
# grid complete!
# Done writing to file: Valuegrid.txt
# Done writing to file: Actiongrid.txt

# %%
valueiteration() # valueiteration for robots and actions
# Out:
# Iteration 100 out of 100
#
# grid complete!

# %%
angle = 6 # can be changed from 0 to 11 to change the angle from 0 to 270 degrees.
printAngle(angle)
showGrid(valuegrid[:,:,angle])
# Out:
# ---- Angle ----
# Radians:  3.14
# Degrees:  180.0
# ---------------
# <img src="data:image/png;base64,...">

# %%
angle = 6 # can be changed from 0 to 11, to change the angle
printAngle(angle)
showGrid(actiongrid[:,:,angle], 1, 3)
# red (3) = land in front
# blue (2) = land on top
# gray (1) = do nothing
# Out:
# ---- Angle ----
# Radians:  3.14
# Degrees:  180.0
# ---------------
# <img src="data:image/png;base64,...">

# %%
print(valuegrid)
# Out:
# [[[ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]
#   [ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]
#   [ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]
#   ...,
#   [ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]
#   [ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]
#   [ 2000.     2000.     2000.    ...,  2000.     2000.     2000.   ]]
#
#  [[-1000.    -1000.    -1000.    ..., -1000.    -1000.    -1000.   ]
#   [ 1620.     2000.     2000.    ...,  2000.     1620.     1620.   ]
#   [ 1800.     2000.     2000.    ...,  2000.     1620.     1800.   ]
#   ...,
#   [ 2000.     1800.     1620.    ...,  2000.     2000.     2000.   ]
#   [ 2000.     1800.     1458.    ...,  2000.     2000.     2000.   ]
#   [-1000.    -1000.    -1000.    ..., -1000.    -1000.    -1000.   ]]
#
#  [[-1000.    -1000.    -1000.    ..., -1000.    -1000.    -1000.   ]
# ...
