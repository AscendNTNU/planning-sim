# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from Valueiteration3d import *
# Out:
# 1

# %%
valueiteration()
# Out:
# 999 out of 1000.
#
# Complete!

# %%
showGrid(valuegrid[:,:,0])
# Out:
# 1
# <img src="data:image/png;base64,...">

# %%
showGrid(valuegrid[:,:,0])
# Out:
# 1
# <img src="data:image/png;base64,...">

# %%
printGrid(valuegrid)
# Out:
# [[ 2000.  2000.  2000.  2000.  1458.  1800.  1800.  2000.  2000.  2000.  1800.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  1800.  1800.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
#  [ 2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.  2000.]
# ...
