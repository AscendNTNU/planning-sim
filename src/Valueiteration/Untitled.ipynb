# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from Valueiteration3d import *
# Out:
# 2018-04-08 10:36:43

# %%
oldValuegrid()
# Out:
# <img src="data:image/png;base64,...">
# loading...
# Iteration 1000 out of 1000
# <img src="data:image/png;base64,...">
# array([[ 2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ],
#        [-1000.        ,   492.53529649,  1077.92306119,  1349.01016388,  1493.56408379,  1579.06263595,  1633.08872811,  1668.31131998,  1691.10667112,  1704.86080713,
#          1711.35159528,  1711.35159528,  1704.86080713,  1691.10667112,  1668.31131998,  1633.08872811,  1579.06263595,  1493.56408379,  1349.01016387,  1077.92306119,
#           492.53529649, -1000.        ],
# ...

# %%
showGrid(valuegrid[:,:,2])

# %%
valuegridWithObst()
# Out:
# <img src="data:image/png;base64,...">
# loading...
# Iteration 1000 out of 1000
# <img src="data:image/png;base64,...">
# array([[ 2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ],
#        [-1000.        ,   492.53529649,  1077.92306118,  1349.01016387,  1493.56408378,  1579.06263595,  1633.0887281 ,  1668.31131997,  1691.10667111,  1704.86080712,
#          1711.35159527,  1711.35159527,  1704.86080712,  1691.10667111,  1668.31131997,  1633.0887281 ,  1579.06263595,  1493.56408378,  1349.01016387,  1077.92306118,
#           492.53529649, -1000.        ],
# ...
