# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from Valueiteration3d import *
# Out:
# 2018-04-23 16:19:54
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
oldValuegrid()
# Out:
# loading...
# Iteration 10000 out of 10000
# <img src="data:image/png;base64,...">
# AT THE END!
# array([[ 2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ],
#        [-1000.        ,   492.53529649,  1077.92306118,  1349.01016387,  1493.56408378,  1579.06263594,  1633.0887281 ,  1668.31131996,  1691.1066711 ,  1704.86080711,
#          1711.35159527,  1711.35159527,  1704.86080711,  1691.1066711 ,  1668.31131996,  1633.0887281 ,  1579.06263594,  1493.56408378,  1349.01016387,  1077.92306118,
#           492.53529649, -1000.        ],
# ...

# %%
showGrid(valuegrid[:,:,2])
# Out:
# <img src="data:image/png;base64,...">

# %%
valuegridWithObst()
# Out:
# <img src="data:image/png;base64,...">
# loading...
# Iteration 1000 out of 1000
# <img src="data:image/png;base64,...">
# array([[ 2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,  2000.        ,
#          2000.        ,  2000.        ],
#        [-1000.        ,   492.53529649,  1077.92306118,  1349.01016387,  1493.56408378,  1579.06263595,  1633.0887281 ,  1668.31131997,  1691.10667111,  1704.86080712,
#          1711.35159527,  1711.35159527,  1704.86080712,  1691.10667111,  1668.31131997,  1633.0887281 ,  1579.06263595,  1493.56408378,  1349.01016387,  1077.92306118,
#           492.53529649, -1000.        ],
# ...
